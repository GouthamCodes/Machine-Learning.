# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\Goutham\ML internship\weather forecast\Project1WeatherDataset.csv")

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
a=list(set(df.Weather))

# %%
a
# Out:
# ['Snow Showers,Fog',
#  'Snow Pellets',
#  'Rain,Snow,Fog',
#  'Clear',
#  'Snow',
#  'Freezing Rain,Snow Grains',
#  'Drizzle,Snow,Fog',
#  'Fog',
#  'Freezing Drizzle',
#  'Rain Showers',
#  'Snow,Haze',
#  'Rain,Snow Grains',
#  'Snow Showers',
#  'Freezing Drizzle,Snow',
#  'Rain,Snow',
#  'Freezing Rain,Ice Pellets,Fog',
#  'Drizzle,Snow',
#  'Drizzle',
#  'Thunderstorms,Rain',
#  'Rain Showers,Fog',
#  'Thunderstorms,Rain Showers,Fog',
#  'Freezing Rain,Fog',
#  'Thunderstorms',
#  'Mostly Cloudy',
#  'Drizzle,Fog',
#  'Thunderstorms,Moderate Rain Showers,Fog',
#  'Moderate Snow',
#  'Rain,Fog',
#  'Drizzle,Ice Pellets,Fog',
#  'Rain,Snow,Ice Pellets',
#  'Moderate Rain,Fog',
#  'Rain Showers,Snow Showers',
#  'Mainly Clear',
#  'Thunderstorms,Rain,Fog',
#  'Snow,Fog',
#  'Rain,Haze',
#  'Haze',
#  'Freezing Rain,Haze',
#  'Rain',
#  'Rain,Ice Pellets',
#  'Snow,Blowing Snow',
#  'Cloudy',
#  'Freezing Drizzle,Fog',
#  'Freezing Rain',
#  'Thunderstorms,Rain Showers',
# ...

# %%
a.sort()

# %%
a
# Out:
# ['Clear',
#  'Cloudy',
#  'Drizzle',
#  'Drizzle,Fog',
#  'Drizzle,Ice Pellets,Fog',
#  'Drizzle,Snow',
#  'Drizzle,Snow,Fog',
#  'Fog',
#  'Freezing Drizzle',
#  'Freezing Drizzle,Fog',
#  'Freezing Drizzle,Haze',
#  'Freezing Drizzle,Snow',
#  'Freezing Fog',
#  'Freezing Rain',
#  'Freezing Rain,Fog',
#  'Freezing Rain,Haze',
#  'Freezing Rain,Ice Pellets,Fog',
#  'Freezing Rain,Snow Grains',
#  'Haze',
#  'Mainly Clear',
#  'Moderate Rain,Fog',
#  'Moderate Snow',
#  'Moderate Snow,Blowing Snow',
#  'Mostly Cloudy',
#  'Rain',
#  'Rain Showers',
#  'Rain Showers,Fog',
#  'Rain Showers,Snow Showers',
#  'Rain,Fog',
#  'Rain,Haze',
#  'Rain,Ice Pellets',
#  'Rain,Snow',
#  'Rain,Snow Grains',
#  'Rain,Snow,Fog',
#  'Rain,Snow,Ice Pellets',
#  'Snow',
#  'Snow Pellets',
#  'Snow Showers',
#  'Snow Showers,Fog',
#  'Snow,Blowing Snow',
#  'Snow,Fog',
#  'Snow,Haze',
#  'Snow,Ice Pellets',
#  'Thunderstorms',
#  'Thunderstorms,Heavy Rain Showers',
# ...

# %%
for i in a:
    print(i,"=i.get_group(0)")
# Out:
# Clear =i.get_group(0)
# Cloudy =i.get_group(0)
# Drizzle =i.get_group(0)
# Drizzle,Fog =i.get_group(0)
# Drizzle,Ice Pellets,Fog =i.get_group(0)
# Drizzle,Snow =i.get_group(0)
# Drizzle,Snow,Fog =i.get_group(0)
# Fog =i.get_group(0)
# Freezing Drizzle =i.get_group(0)
# Freezing Drizzle,Fog =i.get_group(0)
# Freezing Drizzle,Haze =i.get_group(0)
# Freezing Drizzle,Snow =i.get_group(0)
# Freezing Fog =i.get_group(0)
# Freezing Rain =i.get_group(0)
# Freezing Rain,Fog =i.get_group(0)
# Freezing Rain,Haze =i.get_group(0)
# Freezing Rain,Ice Pellets,Fog =i.get_group(0)
# Freezing Rain,Snow Grains =i.get_group(0)
# Haze =i.get_group(0)
# Mainly Clear =i.get_group(0)
# Moderate Rain,Fog =i.get_group(0)
# Moderate Snow =i.get_group(0)
# Moderate Snow,Blowing Snow =i.get_group(0)
# Mostly Cloudy =i.get_group(0)
# Rain =i.get_group(0)
# Rain Showers =i.get_group(0)
# Rain Showers,Fog =i.get_group(0)
# Rain Showers,Snow Showers =i.get_group(0)
# Rain,Fog =i.get_group(0)
# ...

# %% [raw]
# df[]

# %%
#x=df[["Temp_C","Rel Hum_%","Wind Speed_km/h"]]

# %%
y=df.Weather

# %% [raw]
# convert the string form into label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab=LabelEncoder()

# %%
weather=lab.fit_transform(y)

# %%
weather
# Out:
# array([ 7,  7,  9, ..., 35, 35, 35])

# %%
df.Weather
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object

# %%
df["weatherLE"]=weather

# %% [raw]
# Independent and dependent data

# %%
x=df[["Temp_C","Rel Hum_%","Wind Speed_km/h"]]

# %%
y=df.weatherLE

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
i=df.groupby("weatherLE")

# %%
Clear =i.get_group(0)
Cloudy =i.get_group(1)
Drizzle =i.get_group(2)
DrizzleFog =i.get_group(3)
DrizzleIcePelletsFog =i.get_group(4)
DrizzleSnow =i.get_group(5)
DrizzleSnowFog =i.get_group(6)
Fog =i.get_group(7)
FreezingDrizzle =i.get_group(8)
FreezingDrizzleFog =i.get_group(9)
FreezingDrizzleHaze =i.get_group(10)
FreezingDrizzleSnow =i.get_group(11)
FreezingFog =i.get_group(12)
FreezingRain =i.get_group(13)
FreezingRainFog =i.get_group(14)
FreezingRainHaze =i.get_group(15)
FreezingRainIcePelletsFog =i.get_group(16)
FreezingRainSnowGrains =i.get_group(17)
Haze =i.get_group(18)
MainlyClear =i.get_group(19)
ModerateRainFog =i.get_group(20)
ModerateSnow =i.get_group(21)
ModerateSnowBlowingSnow =i.get_group(22)
MostlyCloudy =i.get_group(23)
Rain =i.get_group(24)
RainShowers =i.get_group(25)
RainShowersFog =i.get_group(26)
RainShowersSnowShowers =i.get_group(27)
RainFog =i.get_group(28)
RainHaze =i.get_group(29)
RainIcePellets =i.get_group(30)
RainSnow =i.get_group(31)
RainSnowGrains =i.get_group(32)
RainSnowFog =i.get_group(33)
RainSnowIcePellets =i.get_group(34)
Snow =i.get_group(35)
SnowPellets =i.get_group(36)
SnowShowers =i.get_group(37)
SnowShowersFog =i.get_group(38)
SnowBlowingSnow =i.get_group(39)
SnowFog =i.get_group(40)
SnowHaze =i.get_group(41)
SnowIcePellets =i.get_group(42)
Thunderstorms =i.get_group(43)
ThunderstormsHeavyRainShowers =i.get_group(44)
ThunderstormsModerateRainShowersFog =i.get_group(45)
ThunderstormsRain =i.get_group(46)
ThunderstormsRainShowers =i.get_group(47)
ThunderstormsRainShowersFog =i.get_group(48)
ThunderstormsRainFog =i.get_group(49)

# %%
i.get_group(44)
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 3582  5/29/2012 6:00    10.9               9.0         88                9
#
#       Visibility_km  Press_kPa                           Weather  weatherLE
# 3582            2.4     100.26  Thunderstorms,Heavy Rain Showers         44

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.01)

# %%
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
tree=DecisionTreeClassifier()

# %%
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.predict(X_train)
# Out:
# array([19, 19, 25, ..., 23,  0,  1])

# %%
tree.score(X_test,y_test)
# Out:
# 0.375

# %%
x=float(input("enter the temp:"))
y=int(input("enter the humidity"))
z=int(input("enter the wind speed"))

# %%
if tree.predict([[x,y,z]])[0]==0:
    print("clear")
elif tree.predict([[x,y,z]])[0]==1:
    print("cloudy")
elif tree.predict([[x,y,z]])[0]==2:
    print ("drizzle")
elif tree.predict([[x,y,z]])[0]==3:
    print ("drizzle,fog")
elif tree.predict([[x,y,z]])[0]==4:print ("drizzle,ice pellet,fog")
elif tree.predict([[x,y,z]])[0]==5:print ( "drizzle,snow" )
elif tree.predict([[x,y,z]])[0]==6:print ( "drizzle,snow,fog" )
elif tree.predict([[x,y,z]])[0]==7:print ( "Fog" )
elif tree.predict([[x,y,z]])[0]==8:print ( "freezing drizzle" )
elif tree.predict([[x,y,z]])[0]==9:print ( "fog,freezing drizzle" )
elif tree.predict([[x,y,z]])[0]==10:print ( "haze,freezing drizzle" )
elif tree.predict([[x,y,z]])[0]==11:print ( "snow,freezing drizzle" )
elif tree.predict([[x,y,z]])[0]==12:print ("freezing fog")
elif tree.predict([[x,y,z]])[0]==13:print ( "freezing rain" )
elif tree.predict([[x,y,z]])[0]==14:print ( "freezing rain,fog" )
elif tree.predict([[x,y,z]])[0]==15:print ( "freezing rain,haze" )
elif tree.predict([[x,y,z]])[0]==16:print ( "freezing rain,ice pellets,fog" )
elif tree.predict([[x,y,z]])[0]==17:print ("freezing rain,snow grains")
elif tree.predict([[x,y,z]])[0]==18:print ( "haze" )
elif tree.predict([[x,y,z]])[0]==19:print ( "mainly clear" )
elif tree.predict([[x,y,z]])[0]==20:print ( "moderate rain,fog" )
elif tree.predict([[x,y,z]])[0]==21:print ( "moderate snow" )
elif tree.predict([[x,y,z]])[0]==22:print ("moderate & blowing snow")
elif tree.predict([[x,y,z]])[0]==23:print ( "mostly cloudy" )
elif tree.predict([[x,y,z]])[0]==24:print ( "rain" )
elif tree.predict([[x,y,z]])[0]==25:print ( "rain shower" )
elif tree.predict([[x,y,z]])[0]==26:print ( "rain shower,fog" )
elif tree.predict([[x,y,z]])[0]==27:print ( "rain shower,snow showers" )
elif tree.predict([[x,y,z]])[0]==28:print ( "rain,fog" )
elif tree.predict([[x,y,z]])[0]==29:print ( "rain,haze" )
elif tree.predict([[x,y,z]])[0]==30:print ( "rain,ice pelletes" )
elif tree.predict([[x,y,z]])[0]==31:print ( "rain,snow" )
elif tree.predict([[x,y,z]])[0]==32:print ( "rain,snow grains" )
elif tree.predict([[x,y,z]])[0]==33:print ( "rain,snow,fog" )
elif tree.predict([[x,y,z]])[0]==34:print ( "rain,snow,ice pellets" )
elif tree.predict([[x,y,z]])[0]==35:print ( "snow" )
elif tree.predict([[x,y,z]])[0]==36:print ( "snowpellets" )
elif tree.predict([[x,y,z]])[0]==37:print ( "snowshower" )
elif tree.predict([[x,y,z]])[0]==38:print ( "snowshower,fog" )
elif tree.predict([[x,y,z]])[0]==39:print ( "snow,blowing snow" )
elif tree.predict([[x,y,z]])[0]==40:print ( "snow,fog" )
elif tree.predict([[x,y,z]])[0]==41:print ( "snow,haze" )
elif tree.predict([[x,y,z]])[0]==42:print ( "snow,icepellets" )
elif tree.predict([[x,y,z]])[0]==43:print ( "thunderstroms" )
elif tree.predict([[x,y,z]])[0]==44:print ( "thunderstrom,heavyrainshower" )
elif tree.predict([[x,y,z]])[0]==45:print (  "thunderstroms,moderate")
elif tree.predict([[x,y,z]])[0]==46:print (  "thunderstroms,rain" )
elif tree.predict([[x,y,z]])[0]==47:print (  "thunderstroms,rainshower" )
elif tree.predict([[x,y,z]])[0]==48:print (  "thunderstroms,rain shower,fog" )
elif tree.predict([[x,y,z]])[0]==49:print (  "thunderstroms,rain,fog" )
